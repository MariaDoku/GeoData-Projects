# %%
import geopandas as gpd

# %%
cities = gpd.read_file('belgian_cities.shp')

# %%
cities
# Out:
#             NAME_4                                           geometry
# 0       Anderlecht  POLYGON ((143793.126 166452.379, 143610.878 16...
# 1          Brussel  POLYGON ((147766.293 170637.180, 147826.869 17...
# 2           Elsene  MULTIPOLYGON (((151867.674 167090.660, 151805....
# 3        Etterbeek  POLYGON ((152732.322 169655.021, 152703.407 16...
# 4            Evere  POLYGON ((153968.453 172252.061, 153885.348 17...
# ..             ...                                                ...
# 584        Doische  POLYGON ((166456.205 88160.166, 166362.371 885...
# 585      Florennes  POLYGON ((179950.274 98553.366, 179560.529 985...
# 586  Philippeville  POLYGON ((166456.205 88160.166, 166297.781 879...
# 587      Viroinval  POLYGON ((173013.224 77770.619, 172844.129 770...
# 588       Walcourt  POLYGON ((162424.479 101930.877, 160605.120 10...
#
# [589 rows x 2 columns]

# %%
type(cities)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
cities.head()
# Out:
#        NAME_4                                           geometry
# 0  Anderlecht  POLYGON ((143793.126 166452.379, 143610.878 16...
# 1     Brussel  POLYGON ((147766.293 170637.180, 147826.869 17...
# 2      Elsene  MULTIPOLYGON (((151867.674 167090.660, 151805....
# 3   Etterbeek  POLYGON ((152732.322 169655.021, 152703.407 16...
# 4       Evere  POLYGON ((153968.453 172252.061, 153885.348 17...

# %%
cities.head(6)
# Out:
#        NAME_4                                           geometry
# 0  Anderlecht  POLYGON ((143793.126 166452.379, 143610.878 16...
# 1     Brussel  POLYGON ((147766.293 170637.180, 147826.869 17...
# 2      Elsene  MULTIPOLYGON (((151867.674 167090.660, 151805....
# 3   Etterbeek  POLYGON ((152732.322 169655.021, 152703.407 16...
# 4       Evere  POLYGON ((153968.453 172252.061, 153885.348 17...
# 5   Ganshoren  POLYGON ((146101.131 172823.202, 146056.686 17...

# %%
import matplotlib.pyplot as plt
cities.plot()
# Out:
# <AxesSubplot:>

# %%
len(cities)
# Out:
# 589

# %%
cities.plot(cmap='jet')
# Out:
# <AxesSubplot:>

# %%
AOI = gpd.read_file('area_of_interest_.shp')

# %%
AOI.plot()
# Out:
# <AxesSubplot:>

# %%
fig,ax = plt.subplots(1)
cities.plot(ax = ax)
AOI.plot(ax = ax)
# Out:
# <AxesSubplot:>

# %%
fig,ax = plt.subplots(1)
cities.plot(ax = ax, cmap = 'rainbow', column = 'NAME_4')
AOI.plot(ax = ax)
# Out:
# <AxesSubplot:>

# %%
fig,ax = plt.subplots(1)
cities.plot(ax = ax, cmap = 'rainbow', column = 'NAME_4')
AOI.plot(ax = ax, facecolor = 'yellow')
# Out:
# <AxesSubplot:>

# %%
fig,ax = plt.subplots(1)
cities.plot(ax = ax, cmap = 'rainbow', column = 'NAME_4')
AOI.plot(ax = ax, facecolor = 'yellow')
cities_in_AOI = gpd.overlay(cities,AOI,how = 'intersection')
cities_in_AOI.plot(figsize = (10,10))
# Out:
# <AxesSubplot:>

# %%
cities_in_AOI.plot(figsize = (10,10), cmap = 'jet', column = 'NAME_4')
# Out:
# <AxesSubplot:>
