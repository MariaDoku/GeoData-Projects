# %%
# %matplotlib inline
import geopandas as gpd
g = gpd.read_file('D:\Shp\Guayaqui_Lineas.shp')

# %%
g.columns
# Out:
# Index(['osm_id', 'name', 'highway', 'waterway', 'aerialway', 'barrier',
#        'man_made', 'z_order', 'other_tags', 'SPEED2', 'geometry'],
#       dtype='object')

# %%
g['highway'].value_counts()
# Out:
# residential       1163
# footway            625
# living_street       90
# tertiary            88
# secondary           84
# primary             50
# service             34
# primary_link        23
# trunk_link          23
# trunk               19
# secondary_link      17
# steps                8
# tertiary_link        4
# cycleway             2
# unclassified         1
# track                1
# Name: highway, dtype: int64

# %%
g['waterway'].value_counts()
# Out:
# canal     6
# stream    1
# river     1
# Name: waterway, dtype: int64

# %%
g[g['highway']=='residential'].plot()
# Out:
# <AxesSubplot:>

# %%
g[g['highway']=='primary'].plot()
# Out:
# <AxesSubplot:>

# %%
g[g['highway']=='footway'].plot()
# Out:
# <AxesSubplot:>

# %%
g.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
g2 = g.to_crs(epsg='32717')
g2['length'] = g2.length
g2.head()
# Out:
#   osm_id                     name  highway waterway aerialway barrier  \
# 0      1    Francisco De Orellana    trunk     None      None    None
# 1      1    Francisco De Orellana    trunk     None      None    None
# 2      0    Francisco De Orellana    trunk     None      None    None
# 3      1    Francisco De Orellana    trunk     None      None    None
# 4      1  Rodolfo Baquerizo Nazur  primary     None      None    None
#
#   man_made  z_order                                         other_tags  \
# 0     None        8  "alt_name"=>"Eje","lanes"=>"3","maxspeed"=>"70...
# 1     None       28  "alt_name"=>"Eje","bridge"=>"yes","lanes"=>"3"...
# 2     None        8  "alt_name"=>"Eje","lanes"=>"3","oneway"=>"yes"...
# 3     None       28  "alt_name"=>"Eje","bridge"=>"yes","lanes"=>"3"...
# 4     None        7  "alt_name"=>"Calle 19 NE","lanes"=>"2","oneway...
#
#    SPEED2                                           geometry      length
# ...

# %%
g2[g2['highway']=='primary']['length'].sum()
# Out:
# 20633.07248596893
